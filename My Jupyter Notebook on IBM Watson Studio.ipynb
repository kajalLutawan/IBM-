# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Kajal Lutawan__

# %% [markdown]
# _I am interested in Data Science because of the integration of data in various strategies as well as exploring more in Artificial Intelligence._

# %% [markdown]
# ### The code below is going to calculate the percentage of a test of a mark of 35 out of a total of 40 marks.

# %%
mark = 35
test_total = 40
percentage_of_test = (mark / test_total)*100
print(percentage_of_test, "%")
# Out:
# 87.5 %

# %% [markdown]
# ***
# ***
# ***
